# %% [markdown]
# <h2>Importing Libraries

# %%
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# <h2>Importing Data Set

# %%
import os 
os.chdir(r'D:\IIT Tirupati\ML and Data Science Research Basics\2)Regression\Muiltiple Regression')
print(os.getcwd())
dataset=pd.read_csv('50_Startups.csv')
x = dataset.iloc[:,:-1].values
y=dataset.iloc[:,-1].values
print(x)
# Out:
# D:\IIT Tirupati\ML and Data Science Research Basics\2)Regression\Muiltiple Regression
# [[165349.2 136897.8 471784.1 'New York']
#  [162597.7 151377.59 443898.53 'California']
#  [153441.51 101145.55 407934.54 'Florida']
#  [144372.41 118671.85 383199.62 'New York']
#  [142107.34 91391.77 366168.42 'Florida']
#  [131876.9 99814.71 362861.36 'New York']
#  [134615.46 147198.87 127716.82 'California']
#  [130298.13 145530.06 323876.68 'Florida']
#  [120542.52 148718.95 311613.29 'New York']
#  [123334.88 108679.17 304981.62 'California']
#  [101913.08 110594.11 229160.95 'Florida']
#  [100671.96 91790.61 249744.55 'California']
#  [93863.75 127320.38 249839.44 'Florida']
#  [91992.39 135495.07 252664.93 'California']
#  [119943.24 156547.42 256512.92 'Florida']
#  [114523.61 122616.84 261776.23 'New York']
#  [78013.11 121597.55 264346.06 'California']
#  [94657.16 145077.58 282574.31 'New York']
#  [91749.16 114175.79 294919.57 'Florida']
#  [86419.7 153514.11 0.0 'New York']
# ...

# %% [markdown]
# <h2>Encoding the Categorical Data

# %%
from sklearn.compose import ColumnTransformer 
from sklearn.preprocessing import OneHotEncoder # we use this to convert the Categorical data into the Encoded format this why we use this it's use 
#ct = ColumnTransformer (transformers=[('encoder'  , OneHotEncoder() , [3])], remainder = 'passthrough')
ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [3])], remainder='passthrough')
x = np.array(ct.fit_transform(x))
print(x)
# Out:
# [[0.0 0.0 1.0 165349.2 136897.8 471784.1]
#  [1.0 0.0 0.0 162597.7 151377.59 443898.53]
#  [0.0 1.0 0.0 153441.51 101145.55 407934.54]
#  [0.0 0.0 1.0 144372.41 118671.85 383199.62]
#  [0.0 1.0 0.0 142107.34 91391.77 366168.42]
#  [0.0 0.0 1.0 131876.9 99814.71 362861.36]
#  [1.0 0.0 0.0 134615.46 147198.87 127716.82]
#  [0.0 1.0 0.0 130298.13 145530.06 323876.68]
#  [0.0 0.0 1.0 120542.52 148718.95 311613.29]
#  [1.0 0.0 0.0 123334.88 108679.17 304981.62]
#  [0.0 1.0 0.0 101913.08 110594.11 229160.95]
#  [1.0 0.0 0.0 100671.96 91790.61 249744.55]
#  [0.0 1.0 0.0 93863.75 127320.38 249839.44]
#  [1.0 0.0 0.0 91992.39 135495.07 252664.93]
#  [0.0 1.0 0.0 119943.24 156547.42 256512.92]
#  [0.0 0.0 1.0 114523.61 122616.84 261776.23]
#  [1.0 0.0 0.0 78013.11 121597.55 264346.06]
#  [0.0 0.0 1.0 94657.16 145077.58 282574.31]
#  [0.0 1.0 0.0 91749.16 114175.79 294919.57]
#  [0.0 0.0 1.0 86419.7 153514.11 0.0]
#  [1.0 0.0 0.0 76253.86 113867.3 298664.47]
# ...

# %% [markdown]
# <h2> Splitting the Dataset And Training the DataSet from the Regression

# %%
from sklearn.model_selection import train_test_split 
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size = 0.2 , random_state = 0 ) 
from sklearn.linear_model import LinearRegression
regressor = LinearRegression() 
regressor.fit(x_train , y_train)
# Out:
# LinearRegression()

# %% [markdown]
# <h2>Performing on the Test data Set

# %%
y_pred = regressor.predict(x_test)
np.set_printoptions(precision = 2) 
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))
#print(np.concatenate (y_pred.reshape (len (y_pred),1 ) , y_test.reshape(len(y_test) ,1)) , 1)
# Out:
# [[103015.2  103282.38]
#  [132582.28 144259.4 ]
#  [132447.74 146121.95]
#  [ 71976.1   77798.83]
#  [178537.48 191050.39]
#  [116161.24 105008.31]
#  [ 67851.69  81229.06]
#  [ 98791.73  97483.56]
#  [113969.44 110352.25]
#  [167921.07 166187.94]]

# %%
plt.scatter(y_test, y_pred, color='blue')  # Scatter plot for actual vs predicted
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red', linewidth=2)  # Line for ideal prediction
plt.title('Actual vs Predicted Salary')
plt.xlabel('Actual Salary')
plt.ylabel('Predicted Salary')
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Scatter plot of the training points
ax.scatter(X_train[:, 0], X_train[:, 1], y_train, color='red')

# Create a grid for the hyperplane
x_surf, y_surf = np.meshgrid(np.linspace(X_train[:, 0].min(), X_train[:, 0].max(), 10), 
                             np.linspace(X_train[:, 1].min(), X_train[:, 1].max(), 10))
z_surf = regressor.intercept_ + regressor.coef_[0] * x_surf + regressor.coef_[1] * y_surf

# Plot the hyperplane
ax.plot_surface(x_surf, y_surf, z_surf, alpha=0.5, rstride=100, cstride=100, color='blue')

ax.set_xlabel('Years of Experience (scaled)')
ax.set_ylabel('Age (scaled)')
ax.set_zlabel('Salary')
ax.set_title('Multiple Linear Regression Hyperplane')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 5
#       2 ax = fig.add_subplot(111, projection='3d')
#       4 # Scatter plot of the training points
# ----> 5 ax.scatter(X_train[:, 0], X_train[:, 1], y_train, color='red')
#       7 # Create a grid for the hyperplane
#       8 x_surf, y_surf = np.meshgrid(np.linspace(X_train[:, 0].min(), X_train[:, 0].max(), 10),
#       9                              np.linspace(X_train[:, 1].min(), X_train[:, 1].max(), 10))
#
# NameError: name 'X_train' is not defined
